# %%
import pandas as pd
from database import Station, Observation

# %%
Station.get_by_id('second_test')
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# c:\users\pedro\pycharmprojects\tcc\venv\lib\site-packages\peewee.py in execute_sql(self, sql, params, commit)
#    3004             try:
# -> 3005                 cursor.execute(sql, params or ())
#    3006             except Exception:
#
# OperationalError: could not receive data from server: Software caused connection abort (0x00002745/10053)
#
#
# During handling of the above exception, another exception occurred:
#
# OperationalError                          Traceback (most recent call last)
# <ipython-input-15-29df28426b73> in <module>
# ----> 1 Station.get_by_id('second_test')
#       2
#
# c:\users\pedro\pycharmprojects\tcc\venv\lib\site-packages\peewee.py in get_by_id(cls, pk)
#    6251     @classmethod
#    6252     def get_by_id(cls, pk):
# -> 6253         return cls.get(cls._meta.primary_key == pk)
#    6254
#    6255     @classmethod
#
# c:\users\pedro\pycharmprojects\tcc\venv\lib\site-packages\peewee.py in get(cls, *query, **filters)
#    6240         if filters:
#    6241             sq = sq.filter(**filters)
# -> 6242         return sq.get()
#    6243
#    6244     @classmethod
#
# c:\users\pedro\pycharmprojects\tcc\venv\lib\site-packages\peewee.py in get(self, database)
#    6663         clone._cursor_wrapper = None
#    6664         try:
# -> 6665             return clone.execute(database)[0]
#    6666         except IndexError:
#    6667             sql, params = clone.sql()
#
# c:\users\pedro\pycharmprojects\tcc\venv\lib\site-packages\peewee.py in inner(self, database, *args, **kwargs)
#    1810             raise InterfaceError('Query must be bound to a database in order '
#    1811                                  'to call "%s".' % method.__name__)
# -> 1812         return method(self, database, *args, **kwargs)
#    1813     return inner
#    1814
#
# c:\users\pedro\pycharmprojects\tcc\venv\lib\site-packages\peewee.py in execute(self, database)
#    1881     @database_required
#    1882     def execute(self, database):
# -> 1883         return self._execute(database)
#    1884
#    1885     def _execute(self, database):
#
# c:\users\pedro\pycharmprojects\tcc\venv\lib\site-packages\peewee.py in _execute(self, database)
#    2052     def _execute(self, database):
#    2053         if self._cursor_wrapper is None:
# -> 2054             cursor = database.execute(self)
#    2055             self._cursor_wrapper = self._get_cursor_wrapper(cursor)
#    2056         return self._cursor_wrapper
#
# c:\users\pedro\pycharmprojects\tcc\venv\lib\site-packages\playhouse\postgres_ext.py in execute(self, query, commit, named_cursor, array_size, **context_options)
#     469         if named_cursor:
#     470             commit = __named_cursor__
# --> 471         cursor = self.execute_sql(sql, params, commit=commit)
#     472         if named_cursor:
#     473             cursor = FetchManyCursor(cursor, array_size)
#
# c:\users\pedro\pycharmprojects\tcc\venv\lib\site-packages\peewee.py in execute_sql(self, sql, params, commit)
#    3010             else:
#    3011                 if commit and not self.in_transaction():
# -> 3012                     self.commit()
#    3013         return cursor
#    3014
#
# c:\users\pedro\pycharmprojects\tcc\venv\lib\site-packages\peewee.py in __exit__(self, exc_type, exc_value, traceback)
#    2781             new_type = self.exceptions[exc_type.__name__]
#    2782             exc_args = exc_value.args
# -> 2783             reraise(new_type, new_type(*exc_args), traceback)
#    2784
#    2785
#
# c:\users\pedro\pycharmprojects\tcc\venv\lib\site-packages\peewee.py in reraise(tp, value, tb)
#     181     def reraise(tp, value, tb=None):
#     182         if value.__traceback__ is not tb:
# --> 183             raise value.with_traceback(tb)
#     184         raise value
#     185
#
# c:\users\pedro\pycharmprojects\tcc\venv\lib\site-packages\peewee.py in execute_sql(self, sql, params, commit)
#    3003             cursor = self.cursor(commit)
#    3004             try:
# -> 3005                 cursor.execute(sql, params or ())
#    3006             except Exception:
#    3007                 if self.autorollback and not self.in_transaction():
#
# OperationalError: could not receive data from server: Software caused connection abort (0x00002745/10053)

# %%
max_observations = 10
station = Station.get_by_id('second_test')
observations_select = Observation.select(
    Observation.channel,
    Observation.time,
    Observation.sample_frequency,
    Observation.sample_count,
    Observation.rms,
    Observation.sample_data,
    Observation.crest,
    Observation.peak_to_peak,
    Observation.kurtosis,
).where(Observation.station == station).limit(max_observations)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# c:\users\pedro\pycharmprojects\tcc\venv\lib\site-packages\peewee.py in execute_sql(self, sql, params, commit)
#    3004             try:
# -> 3005                 cursor.execute(sql, params or ())
#    3006             except Exception:
#
# OperationalError: could not receive data from server: Software caused connection abort (0x00002745/10053)
#
#
# During handling of the above exception, another exception occurred:
#
# OperationalError                          Traceback (most recent call last)
# <ipython-input-10-e5f740b5b41b> in <module>
#       1 max_observations = 10
# ----> 2 station = Station.get_by_id('second_test')
#       3 observations_select = Observation.select(
#       4     Observation.channel,
#       5     Observation.time,
#
# c:\users\pedro\pycharmprojects\tcc\venv\lib\site-packages\peewee.py in get_by_id(cls, pk)
#    6251     @classmethod
#    6252     def get_by_id(cls, pk):
# -> 6253         return cls.get(cls._meta.primary_key == pk)
#    6254
#    6255     @classmethod
#
# c:\users\pedro\pycharmprojects\tcc\venv\lib\site-packages\peewee.py in get(cls, *query, **filters)
#    6240         if filters:
#    6241             sq = sq.filter(**filters)
# -> 6242         return sq.get()
#    6243
#    6244     @classmethod
#
# c:\users\pedro\pycharmprojects\tcc\venv\lib\site-packages\peewee.py in get(self, database)
#    6663         clone._cursor_wrapper = None
#    6664         try:
# -> 6665             return clone.execute(database)[0]
#    6666         except IndexError:
#    6667             sql, params = clone.sql()
#
# c:\users\pedro\pycharmprojects\tcc\venv\lib\site-packages\peewee.py in inner(self, database, *args, **kwargs)
#    1810             raise InterfaceError('Query must be bound to a database in order '
#    1811                                  'to call "%s".' % method.__name__)
# -> 1812         return method(self, database, *args, **kwargs)
#    1813     return inner
#    1814
#
# c:\users\pedro\pycharmprojects\tcc\venv\lib\site-packages\peewee.py in execute(self, database)
#    1881     @database_required
#    1882     def execute(self, database):
# -> 1883         return self._execute(database)
#    1884
#    1885     def _execute(self, database):
#
# c:\users\pedro\pycharmprojects\tcc\venv\lib\site-packages\peewee.py in _execute(self, database)
#    2052     def _execute(self, database):
#    2053         if self._cursor_wrapper is None:
# -> 2054             cursor = database.execute(self)
#    2055             self._cursor_wrapper = self._get_cursor_wrapper(cursor)
#    2056         return self._cursor_wrapper
#
# c:\users\pedro\pycharmprojects\tcc\venv\lib\site-packages\playhouse\postgres_ext.py in execute(self, query, commit, named_cursor, array_size, **context_options)
#     469         if named_cursor:
#     470             commit = __named_cursor__
# --> 471         cursor = self.execute_sql(sql, params, commit=commit)
#     472         if named_cursor:
#     473             cursor = FetchManyCursor(cursor, array_size)
#
# c:\users\pedro\pycharmprojects\tcc\venv\lib\site-packages\peewee.py in execute_sql(self, sql, params, commit)
#    3010             else:
#    3011                 if commit and not self.in_transaction():
# -> 3012                     self.commit()
#    3013         return cursor
#    3014
#
# c:\users\pedro\pycharmprojects\tcc\venv\lib\site-packages\peewee.py in __exit__(self, exc_type, exc_value, traceback)
#    2781             new_type = self.exceptions[exc_type.__name__]
#    2782             exc_args = exc_value.args
# -> 2783             reraise(new_type, new_type(*exc_args), traceback)
#    2784
#    2785
#
# c:\users\pedro\pycharmprojects\tcc\venv\lib\site-packages\peewee.py in reraise(tp, value, tb)
#     181     def reraise(tp, value, tb=None):
#     182         if value.__traceback__ is not tb:
# --> 183             raise value.with_traceback(tb)
#     184         raise value
#     185
#
# c:\users\pedro\pycharmprojects\tcc\venv\lib\site-packages\peewee.py in execute_sql(self, sql, params, commit)
#    3003             cursor = self.cursor(commit)
#    3004             try:
# -> 3005                 cursor.execute(sql, params or ())
#    3006             except Exception:
#    3007                 if self.autorollback and not self.in_transaction():
#
# OperationalError: could not receive data from server: Software caused connection abort (0x00002745/10053)
